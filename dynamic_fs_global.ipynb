# %% [markdown]
# ### focus stacking w.r.t. distance from focus

# %%
import numpy as np
import subprocess
import glob
import skimage.io as imio
import re
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# %%
from awnet import pwc_5x5_sigmoid_bilinear   # cm:import AWnet model
import torch

AWnet = pwc_5x5_sigmoid_bilinear.pwc_residual().cuda()
AWnet.load_state_dict(torch.load('awnet/fs_31_all_0.02402605_dict.pkl'))
AWnet = AWnet.eval()

import warnings
warnings.filterwarnings("ignore")

def fuseTwoImages(I, J_hat):
    with torch.no_grad():
        fusedTensor,warp,mask = AWnet(J_hat,I)
    return fusedTensor, warp, mask

def fuse_awnet(a, b):
    #a = np.pad(a, ((200, 200), (128, 128), (0, 0)), 'constant')
    #b = np.pad(b, ((200, 200), (128, 128), (0, 0)), 'constant')
    # a = np.pad(a, ((100, 100), (64, 64), (0, 0)), 'constant')
    # b = np.pad(b, ((100, 100), (64, 64), (0, 0)), 'constant')
    a = a[56:-56, 128:-128]
    a = cv2.resize(a,(896, 512))
#     b = cv2.resize(b,(1024, 640))
    print(a.shape)

    H, W, C = a.shape

#     c = []
#     for xb in range(0, H, 512):
#         for yb in range(0, W, 512):
#             aa = a[xb:xb+512, yb:yb+512, :]
#             bb = b[xb:xb+512, yb:yb+512, :]
#             #print(aa.shape, bb.shape)
#             aa = torch.Tensor(aa[np.newaxis, ...].transpose(0, 3, 1, 2)/255.).cuda()
#             bb = torch.Tensor(bb[np.newaxis, ...].transpose(0, 3, 1, 2)/255.).cuda()
#             cc, _, _ = fuseTwoImages(aa, bb)
#             c.append(cc[0])
#             #print(cc[0].cpu().detach().numpy().transpose(1, 2, 0).shape)
#     fuse_img = np.zeros(a.shape)
#     kz = 0
#     for xb in range(0, H, 512):
#         for yb in range(0, W, 512):
#             fuse_img[xb:xb+512, yb:yb+512] = c[kz].cpu().detach().numpy().transpose(1, 2, 0)
#             kz +=1
    a = torch.Tensor(a[np.newaxis, ...].transpose(0, 3, 1, 2)/255.).cuda()
    b = torch.Tensor(b[np.newaxis, ...].transpose(0, 3, 1, 2)/255.).cuda()
    c, _, _ = fuseTwoImages(a, b)
    fused_img = c[0].cpu().detach().numpy().transpose(1, 2, 0)
            
    return fused_img

# %%
## camera behavior
def initialFocus(sid=0):
    #10.42.0.90: local 10.236.176.75: ip
    cmD='ssh nvidia@10.236.176.152 "sudo ~/Desktop/testCamera -id '+str(sid)+' -init "'
    pop=subprocess.run(cmD, stdout=subprocess.PIPE, shell=True)
    return pop.stdout
def moveFocus(sid=0, pos=512):
    cmD='ssh nvidia@10.236.176.152 "sudo ~/Desktop/testCamera -id '+str(sid)+' -mod '+str(pos)+'"'
    pop=subprocess.run(cmD, stdout=subprocess.PIPE, shell=True)
    return pop.stdout
def setFocus(sid=0, pos=512):
    cmD='ssh nvidia@10.236.176.152 "sudo ~/Desktop/testCamera -id '+str(sid)+' -set '+str(pos)+'"'
    pop=subprocess.run(cmD, stdout=subprocess.PIPE, shell=True)
    return pop.stdout

def grab_image(sid=0, imres=8):
# I will use the file name dbGrab.... for the image grabbed from the camera. First step is to get rid of previously grabbed images

    subprocess.run('ssh nvidia@10.236.176.152 "rm dbGrab*"', \
                   stdout=subprocess.PIPE, shell=True)

    # ok, now let's grab an image on the tegra
    subprocess.run('ssh nvidia@10.236.176.152 "nvgstcapture-1.0 -m 1 --sensor-id '+str(sid)+' -A --capture-auto 1 \
                    --file-name dbGrab --image-res '+str(imres)+'"', stdout=subprocess.PIPE, shell=True)
    subprocess.run('scp nvidia@10.236.176.152:dbGrab* .', \
                   stdout=subprocess.PIPE, shell=True)
    #ok, now let's find the file name of the image we just grabbed and transfered 
    pop=subprocess.run('ls',stdout=subprocess.PIPE, shell=True)
    rePop=pop.stdout
    rePop=rePop.decode("utf-8")
    fileName = re.search(r'dbGrab(.*).jpg', rePop)
    fileName=fileName.group()
    pop=imio.imread(fileName)
#     pop=skimage.transform.rotate(pop,180)
    subprocess.run('mv dbGrab* photo_arch/', \
                   stdout=subprocess.PIPE, shell=True)
    
    return pop

# %%
from quad_solver import solver
import torch.nn as nn
import torch.nn.functional as F
import pickle
import cv2
import torch

class pixel_estimator_with_weights(nn.Module):
    def __init__(self, Weights,device = "cuda:0"):
        ## Default: gpu mode
        super(pixel_estimator_with_weights, self).__init__()
        self.device = torch.device(device)
        self.w1 = torch.from_numpy(Weights[0].transpose(3,2,0,1)).to(self.device)
        self.b1 = torch.from_numpy(Weights[1]).to(self.device)
        self.w2 = torch.tensor(Weights[2].transpose(3,2,0,1)).to(self.device)
        self.b2 = torch.tensor(Weights[3]).to(self.device)
        self.w3 = torch.tensor(Weights[4].transpose(3,2,0,1)).to(self.device)
        self.b3 = torch.tensor(Weights[5]).to(self.device)
        self.w4 = torch.tensor(Weights[6]).reshape(4,4,8,1024).permute(3,2,0,1).to(self.device)
        self.b4 = torch.tensor(Weights[7]).to(self.device)
        self.w5 = torch.tensor(Weights[8]).reshape(1,1,1024,512).permute(3,2,0,1).to(self.device)
        self.b5 = torch.tensor(Weights[9]).to(self.device)
        self.w6 = torch.tensor(Weights[10]).reshape(1,1,512,10).permute(3,2,0,1).to(self.device)
        self.b6 = torch.tensor(Weights[11]).to(self.device)
        self.w7 = torch.tensor(Weights[12]).reshape(1,1,10,1).permute(3,2,0,1).to(self.device)
        self.b7 = torch.tensor(Weights[13]).to(self.device)

    def forward(self, x):
        x = F.relu(F.conv2d(x,self.w1,bias = self.b1,stride=1))
        x = F.relu(F.conv2d(x,self.w2,bias = self.b2,stride=1,dilation=8))
        x = F.relu(F.conv2d(x,self.w3,bias = self.b3,stride=1,dilation=32))
        x = F.leaky_relu(F.conv2d(x,self.w4,bias = self.b4,stride=1,dilation=128),0.1)
        x = F.leaky_relu(F.conv2d(x,self.w5,bias = self.b5,stride=1),0.1)
        x = F.leaky_relu(F.conv2d(x,self.w6,bias = self.b6,stride=1),0.1)
        x = F.conv2d(x,self.w7,bias = self.b7,stride=1)
        return x
    
model = torch.load('autofocus.pth')
model.eval()

def save_imgs(imgs, curr):
    t = int(time.time()%100000)

    for i, img in enumerate(imgs):
        cv2.imwrite("dynamic_fs/{:d}_s{}_{:02d}.jpg".format(t, curr, i), (img[..., ::-1]/img.max()*255.).astype(np.uint8))

# %%
def crop_patches(img, window= 1023, step = 512):
    patches = []
    H, W = img.shape
    for i in range(0, H-step, step):
        for j in range(0, W-step, step):
            patches.append(img[i:i+window, j:j+window])
    return np.stack(patches)

def dist_est(img, curr = 1000, last_dist_map = None, last_move_steps = None, masks = None):
    img = np.pad(img, ((200, 200), (128, 128)), 'reflect')
    plt.imshow(img)
    plt.show()
    H, W = img.shape
    
    patches = crop_patches(img)
    patches = torch.from_numpy(patches).float().unsqueeze(1).cuda()

    results = []
    with torch.no_grad():
        for i in range(patches.size()[0]):
            results.append(model(patches[i:i+1]))
    results = torch.stack(results)

    results = results.cpu().numpy()
    results = results.squeeze()
    
    if last_dist_map is None:
        last_dist_map = np.ones((H-512, W-512))

    k = 0
    sigma =1.5
    n_img = np.zeros((H-512, W-512))
    for i in range(0, H-512, 512):
        for j in range(0, W-512, 512):
            n_img[i:i+512, j:j+512] = results[k]
            k += 1
    n_img[n_img < sigma] = 0
    #n_img[last_dist_map==0]=0
    masks.append((n_img < sigma))
    if masks is not None:
        for kkk in range(max(0, len(masks)-2), len(masks)):
            n_img[masks[kkk]] = 0

        
    plt.imshow((n_img < sigma).astype(np.float32), cmap = 'gray')
    #plt.colorbar()
    plt.show()
    #cv2.imwrite('dynamic_fs/{}.jpg'.format(int(time.time()%100000)), ((n_img < sigma)*255.0).astype(np.uint8))
#     plt.hist(n_img.flatten(), bins = 10)
#     plt.show()

    if last_move_steps is not None:
        ## Focus direction: simple check
        mapa = n_img - last_move_steps
        mapb = -n_img - last_move_steps
        diffa = np.abs(mapa) - last_dist_map
        diffb = np.abs(mapb) - last_dist_map
        mask = (np.abs(diffa) < np.abs(diffb)).astype(np.float64)
        n_img = (n_img * mask + (1-mask) * (-n_img))
        
    dist_vec = n_img.flatten()
    dist_vec = dist_vec[dist_vec!=0]
    #dist_vec = dist_vec[np.abs(dist_vec)>1.5]
    plt.figure()
    n, bins, patches = plt.hist(dist_vec, bins=10)

    idx_sorted = np.argsort(n)[::-1]
    flag = False
    for i in range(len(n)):
        dist_to_move = -(bins[idx_sorted[i]]+bins[idx_sorted[i]+1])/2
        #print("trial {}: est curr: {}".format(i, curr + solver(curr, dist_to_move)))
        if (curr + solver(curr, dist_to_move) > 375) and (curr + solver(curr, dist_to_move) < 1100) and (abs(dist_to_move)>1.5*sigma):
            flag = True
            break
    flag = True
    plt.show()
    

    return flag, np.abs(n_img), dist_to_move, masks

# %%
curr = 700
# setFocus(pos = curr)
# img = grab_image()
# plt.figure(figsize=(10., 8.))
# plt.imshow(img)
# plt.show()

# %%
dist_map = None
dist_to_move = None
masks = []
imgs = []
currs = []
currs.append(curr)
lasts = []

last = None

# %%
for i in range(4):
    print("round: ", i)

    setFocus(pos = curr)
    img = grab_image()
    imgs.append(img)
    gray_img = rgb2gray(img)

    flag, dist_map, dist_to_move, masks = dist_est(gray_img, curr, dist_map, dist_to_move, masks)
    
#     binary_maps.append((dist_map < 1).astype(np.float32))
#     mask = np.zeros(dist_map.shape)
#     for num_mem in range(max(0, len(binary_maps)-1), len(binary_maps)):
#         mask = mask + binary_maps[num_mem]
#     mask = (mask >= 1)
        

    if flag is False:
        break
    print("distance to move: ", dist_to_move)
    curr = curr + solver(curr, dist_to_move)
    curr = np.clip(curr, 450, 1000)
#     if np.abs(curr - currs[-1]) > 50 and np.abs(curr - np.stack(currs)).min() < 50:
#         print("break curr1: ", curr)
#         break
#     elif (curr==450 and np.stack(currs).min() < 475):
#         print("break curr2: ", curr)
#         break
#     else:
#         currs.append(curr)
    currs.append(curr)
    
    print("round {} -- current focus pos is: {}".format(i+1, curr))
    
    if last is not None:

        last = fuse_awnet(img, last)
    else:
        #last = np.pad(img, ((200, 200), (128, 128), (0, 0)), 'constant')
        last = img[56:-56, 128:-128]
        last = cv2.resize(img, (896, 512))

    plt.imshow(last)
    plt.show()
    lasts.append(last)
# Out:
# round:  0
# distance to move:  -7.349930012226105
# round 1 -- current focus pos is: 450.0
# round:  1
# distance to move:  7.02835829257965
# round 2 -- current focus pos is: 754.4378895005348
# (512, 896, 3)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# round:  2
# distance to move:  -3.6476143360137927
# round 3 -- current focus pos is: 577.4065210464094
# (512, 896, 3)
# round:  3
# distance to move:  2.5302807331085204
# round 4 -- current focus pos is: 693.5221799676665
# (512, 896, 3)

# %%
imgs = np.stack(imgs)
#     print(dist_map)
save_imgs(imgs, currs[0])
save_imgs(lasts, 1000+currs[0])
